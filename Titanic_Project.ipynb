# %% [markdown]
# <a href="https://colab.research.google.com/github/ali-zach/Titanic1/blob/main/Titanic_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
# !dir
# Out:
# drive  sample_data  test.csv  train.csv

# %%
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
train.shape
# Out:
# (891, 12)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %%
train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# VISUALISASI DATA

# %% [markdown]
# # Simple Bar Chart

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train["Sex"].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
count_sex = train['Sex'].value_counts()

index_sex = count_sex.index
values_sex = count_sex.values

# %%
values_sex
# Out:
# array([577, 314])

# %%
index_sex
# Out:
# Index(['male', 'female'], dtype='object')

# %%
fig = plt.figure(figsize=(10,5))
plt.bar(index_sex,values_sex,color="maroon",width=0.7)

plt.xlabel("Jenis Kelamin")
plt.ylabel("Jumlah Penumpang")
plt.title("Chart JUmlah Penumpang Berdasarkan Jenis Kelamin")

plt.show()

# %%
def barchart(column) :
 count = train[column].value_counts()

 index = count.index
 values = count.values

 fig  = plt.figure(figsize=(10,5))
 plt.bar(index,values,color="maroon",width=0.7)

 plt.show()

# %%
barchart("Sex")

# %%
barchart("Pclass")

# %%
barchart("Embarked")

# %%
barchart("SibSp")

# %%
barchart("Parch")

# %% [markdown]
# Grouped Barchart

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
survived = train.groupby(["Survived","Sex"]).count()['PassengerId'].reset_index()

# %%
survived
# Out:
#    Survived     Sex  PassengerId
# 0         0  female           81
# 1         0    male          468
# 2         1  female          233
# 3         1    male          109

# %%
def group_barchart(column):
  survived = train.groupby(["Survived",column]).count()["PassengerId"].reset_index()

  g = sns.catplot(
      data=survived,kind="bar",
      x="Survived",y="PassengerId",hue=column,
      palette="dark",height=6)

# %%
group_barchart("Sex")

# %%
group_barchart("Pclass")

# %% [markdown]
# Histogram

# %%
fig,ax = plt.subplots(figsize=(10,7))
ax.hist(train.Age)
plt.show()

# %%
fig,ax = plt.subplots(figsize=(10,7))
ax.hist(train.Fare)

plt.show()

# %% [markdown]
# KDE Plot

# %%
facet = sns.FacetGrid(train,hue="Survived",aspect=4)
facet.map(sns.kdeplot,"Age",fill=True)
facet.add_legend()
plt.show()

# %%
facet = sns.FacetGrid(train,hue="Survived",aspect=4)
facet.map(sns.kdeplot,"Fare",fill=True)
facet.add_legend()
plt.show()

# %% [markdown]
# PREPROSESING DATA

# %% [markdown]
#  ## Mengisi Missing Value

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
test.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %% [markdown]
# ## Mengisi Missing Value Categorical Data

# %% [markdown]
# ## Mengisi Missing Value Embarked

# %%
train[train['Embarked'].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 61   female  38.0      0      0  113572  80.0   B28      NaN
# 829  female  62.0      0      0  113572  80.0   B28      NaN

# %%
train['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
# cari modus dari 'Embarked'
modus_embarked = train['Embarked'].mode()[0]
modus_embarked
# Out:
# 'S'

# %%
 # mengisi missing value
train['Embarked'] = train['Embarked'].fillna(modus_embarked)

# %%
# cek missing value
train[train['Embarked'].isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
# cek missing value di index 61
train[train['Embarked'].index==61]
# Out:
#     PassengerId  Survived  Pclass                 Name     Sex   Age  SibSp  \
# 61           62         1       1  Icard, Miss. Amelie  female  38.0      0
#
#     Parch  Ticket  Fare Cabin Embarked
# 61      0  113572  80.0   B28        S

# %% [markdown]
# Missing Value Age dengan rata-rata/mean

# %%
# mencarii mean 'Age'

mean_age = train["Age"].mean()
mean_age
# Out:
# 29.69911764705882

# %%
# mengubah null dengan mean pada 'train'

train['Age'] = train['Age'].fillna(mean_age)

# %%
# mean 'Age' pada 'test'

mean_age_test = test['Age'].mean()
mean_age_test
# Out:
# 30.272590361445783

# %%
# menggani null dengan mean

test['Age'] = test['Age'].fillna(mean_age_test)

# %% [markdown]
# Missing Value data 'Fare'

# %%
# mean data 'Fare'

mean_fare_test = test['Fare'].mean()
test['Fare'] = test['Fare'].fillna(mean_fare_test)

# %% [markdown]
# Drop 'Cabin' karen terlalu banyakyg missing value

# %%
train = train.drop(['Cabin'], axis=1)
test = test.drop(['Cabin'], axis=1)

# %%
# cek isnull

train.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
test.isnull().sum()
# Out:
# PassengerId    0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %% [markdown]
# CONVERT DATA to NUMERIC

# %% [markdown]
# Convert Data to Sex

# %%
# Menampilkaan head data

train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %%
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Embarked
# 0  34.5      0      0   330911   7.8292        Q
# 1  47.0      1      0   363272   7.0000        S
# 2  62.0      0      0   240276   9.6875        Q
# 3  27.0      0      0   315154   8.6625        S
# 4  22.0      1      1  3101298  12.2875        S

# %%
# Binary Converting

sex_mapping = {'male':1,'female':0}
train['Sex'] = train['Sex'].map(sex_mapping)
test['Sex'] = test['Sex'].map(sex_mapping)

# %%
# cek data
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
#
#              Ticket     Fare Embarked
# 0         A/5 21171   7.2500        S
# 1          PC 17599  71.2833        C
# 2  STON/O2. 3101282   7.9250        S
# 3            113803  53.1000        S
# 4            373450   8.0500        S

# %%
train.iloc[-145]
# Out:
# PassengerId                            747
# Survived                                 0
# Pclass                                   3
# Name           Abbott, Mr. Rossmore Edward
# Sex                                      1
# Age                                   16.0
# SibSp                                    1
# Parch                                    1
# Ticket                           C.A. 2673
# Fare                                 20.25
# Embarked                                 S
# Name: 746, dtype: object

# %% [markdown]
# CONVER DATA to EMBARKED dengan One Hot Encoding

# %%
embarked = train[('Embarked')]
dummies = pd.get_dummies(embarked)

# cek
dummies.head()
# Out:
#    C  Q  S
# 0  0  0  1
# 1  1  0  0
# 2  0  0  1
# 3  0  0  1
# 4  0  0  1

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
#
#              Ticket     Fare Embarked
# 0         A/5 21171   7.2500        S
# 1          PC 17599  71.2833        C
# 2  STON/O2. 3101282   7.9250        S
# 3            113803  53.1000        S
# 4            373450   8.0500        S

# %%
# menggabungkan dummies dengan data train

train = pd.merge(train.reset_index(), dummies.reset_index())

# cek
train.head()
# Out:
#    index  PassengerId  Survived  Pclass  \
# 0      0            1         0       3
# 1      1            2         1       1
# 2      2            3         1       3
# 3      3            4         1       1
# 4      4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
#
#              Ticket     Fare Embarked  C  Q  S
# 0         A/5 21171   7.2500        S  0  0  1
# 1          PC 17599  71.2833        C  1  0  0
# 2  STON/O2. 3101282   7.9250        S  0  0  1
# 3            113803  53.1000        S  0  0  1
# ...

# %%
# hapus kolom yangtidak dipakai (index dan Embarked)

train = train.drop(['index','Embarked'],axis=1)

# %%
#hal yg sama dilakukan pada data test

embarked_tes = test[('Embarked')]
dummies_test = pd.get_dummies(embarked)

# %%
test = pd.merge(test.reset_index(), dummies_test.reset_index())
test = test.drop(['index','Embarked'],axis=1)
test.head()
# Out:
#    PassengerId  Pclass                                          Name  Sex  \
# 0          892       3                              Kelly, Mr. James    1
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)    0
# 2          894       2                     Myles, Mr. Thomas Francis    1
# 3          895       3                              Wirz, Mr. Albert    1
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)    0
#
#     Age  SibSp  Parch   Ticket     Fare  C  Q  S
# 0  34.5      0      0   330911   7.8292  0  0  1
# 1  47.0      1      0   363272   7.0000  1  0  0
# 2  62.0      0      0   240276   9.6875  0  0  1
# 3  27.0      0      0   315154   8.6625  0  0  1
# 4  22.0      1      1  3101298  12.2875  0  0  1

# %% [markdown]
# EXTRACT Data Title From Name and Convert Title

# %%
train['Title'] = train['Name'].str.extract(' ([A-Za-z]+)\.', expand=False)

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
#
#              Ticket     Fare  C  Q  S Title
# 0         A/5 21171   7.2500  0  0  1    Mr
# 1          PC 17599  71.2833  1  0  0   Mrs
# 2  STON/O2. 3101282   7.9250  0  0  1  Miss
# 3            113803  53.1000  0  0  1   Mrs
# 4            373450   8.0500  0  0  1    Mr

# %%
# merubah title menjadi angka
title_mapping = {"Mr":0,"Miss":1,"Mrs":2,
                 "Master":3,"Dr":3,"Rev":3,"Col":3,"Major":3,"Mlle":3,"Countess":3,
                 "Capt":3,"Ms":3,"Lady":3,"Jonkheer":3,"Don":3,"Dona":3,"Mme":3,"Sir":3}

train['Title'] = train['Title'].map(title_mapping)
#cek
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
#
#              Ticket     Fare  C  Q  S  Title
# 0         A/5 21171   7.2500  0  0  1      0
# 1          PC 17599  71.2833  1  0  0      2
# 2  STON/O2. 3101282   7.9250  0  0  1      1
# 3            113803  53.1000  0  0  1      2
# 4            373450   8.0500  0  0  1      0

# %% [markdown]
# mengubah di data "test"

# %%
test['Title'] = test['Name'].str.extract(' ([A-Za-z]+)\.', expand=False)

test.head()
# Out:
#    PassengerId  Pclass                                          Name  Sex  \
# 0          892       3                              Kelly, Mr. James    1
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)    0
# 2          894       2                     Myles, Mr. Thomas Francis    1
# 3          895       3                              Wirz, Mr. Albert    1
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)    0
#
#     Age  SibSp  Parch   Ticket     Fare  C  Q  S Title
# 0  34.5      0      0   330911   7.8292  0  0  1    Mr
# 1  47.0      1      0   363272   7.0000  1  0  0   Mrs
# 2  62.0      0      0   240276   9.6875  0  0  1    Mr
# 3  27.0      0      0   315154   8.6625  0  0  1    Mr
# 4  22.0      1      1  3101298  12.2875  0  0  1   Mrs

# %%
test['Title'] = test['Title'].map(title_mapping)
#cek
test.head()
# Out:
#    PassengerId  Pclass                                          Name  Sex  \
# 0          892       3                              Kelly, Mr. James    1
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)    0
# 2          894       2                     Myles, Mr. Thomas Francis    1
# 3          895       3                              Wirz, Mr. Albert    1
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)    0
#
#     Age  SibSp  Parch   Ticket     Fare  C  Q  S  Title
# 0  34.5      0      0   330911   7.8292  0  0  1      0
# 1  47.0      1      0   363272   7.0000  1  0  0      2
# 2  62.0      0      0   240276   9.6875  0  0  1      0
# 3  27.0      0      0   315154   8.6625  0  0  1      0
# 4  22.0      1      1  3101298  12.2875  0  0  1      2

# %% [markdown]
# Selected Column

# %%
train.shape,test.shape
# Out:
# ((891, 14), (418, 13))

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
#
#              Ticket     Fare  C  Q  S  Title
# 0         A/5 21171   7.2500  0  0  1      0
# 1          PC 17599  71.2833  1  0  0      2
# 2  STON/O2. 3101282   7.9250  0  0  1      1
# 3            113803  53.1000  0  0  1      2
# 4            373450   8.0500  0  0  1      0

# %%
test.head()
# Out:
#    PassengerId  Pclass                                          Name  Sex  \
# 0          892       3                              Kelly, Mr. James    1
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)    0
# 2          894       2                     Myles, Mr. Thomas Francis    1
# 3          895       3                              Wirz, Mr. Albert    1
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)    0
#
#     Age  SibSp  Parch   Ticket     Fare  C  Q  S  Title
# 0  34.5      0      0   330911   7.8292  0  0  1      0
# 1  47.0      1      0   363272   7.0000  1  0  0      2
# 2  62.0      0      0   240276   9.6875  0  0  1      0
# 3  27.0      0      0   315154   8.6625  0  0  1      0
# 4  22.0      1      1  3101298  12.2875  0  0  1      2

# %%
train = train.drop(["PassengerId","Name","Ticket"],axis=1)
test = test.drop(["PassengerId","Name","Ticket"],axis=1)

# %%
train.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare  C  Q  S  Title
# 0         0       3    1  22.0      1      0   7.2500  0  0  1      0
# 1         1       1    0  38.0      1      0  71.2833  1  0  0      2
# 2         1       3    0  26.0      0      0   7.9250  0  0  1      1
# 3         1       1    0  35.0      1      0  53.1000  0  0  1      2
# 4         0       3    1  35.0      0      0   8.0500  0  0  1      0

# %%
test.head()
# Out:
#    Pclass  Sex   Age  SibSp  Parch     Fare  C  Q  S  Title
# 0       3    1  34.5      0      0   7.8292  0  0  1      0
# 1       3    0  47.0      1      0   7.0000  1  0  0      2
# 2       2    1  62.0      0      0   9.6875  0  0  1      0
# 3       3    1  27.0      0      0   8.6625  0  0  1      0
# 4       3    0  22.0      1      1  12.2875  0  0  1      2

# %% [markdown]
# MODELLING

# %%
# IMPORT CLASSIFIER MODULE

from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC

from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

# %%
train.shape,test.shape
# Out:
# ((891, 11), (418, 10))

# %%
train_data = train.drop('Survived',axis=1)
target = train["Survived"]

# %%
# MODELLING
k_fold = KFold(n_splits=5,shuffle=True,random_state=0)

# GaussianNB
clf = GaussianNB()
scoring = 'accuracy'
score = cross_val_score(clf,train_data,target,cv=k_fold,n_jobs=1,scoring=scoring)

print(score)
# Out:
# [0.78212291 0.78651685 0.78089888 0.8258427  0.82022472]

# %%
score.mean()
# Out:
# 0.7991212102190698

# %%
# MODELLING
k_fold = KFold(n_splits=5,shuffle=True,random_state=0)

# DecisionTree
clf = DecisionTreeClassifier()
scoring = 'accuracy'
score = cross_val_score(clf,train_data,target,cv=k_fold,n_jobs=1,scoring=scoring)

print(score)
# Out:
# [0.75418994 0.78651685 0.78651685 0.78089888 0.78651685]

# %%
score.mean()
# Out:
# 0.7789278764672651

# %% [markdown]
# KARENA mean score tertinggi dengan menggunakan GaussianNB, maka PREDICTION menggunaka GaussianNB

# %%
test.head()
# Out:
#    Pclass  Sex   Age  SibSp  Parch     Fare  C  Q  S  Title
# 0       3    1  34.5      0      0   7.8292  0  0  1      0
# 1       3    0  47.0      1      0   7.0000  1  0  0      2
# 2       2    1  62.0      0      0   9.6875  0  0  1      0
# 3       3    1  27.0      0      0   8.6625  0  0  1      0
# 4       3    0  22.0      1      1  12.2875  0  0  1      2

# %%
clf = GaussianNB()
clf.fit(train_data,target)
# Out:
# GaussianNB()

# %%
prediction = clf.predict(test)

# %%
#simpan dataframe 'test'
df_test = pd.read_csv("test.csv")
submission = pd.DataFrame({
            "PassengerId":df_test['PassengerId'],
            "Survived":prediction
            })
submission.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         1
# 2          894         0
# 3          895         0
# 4          896         1

# %%
# save PREDIKSI
submission.to_csv("submit.csv",index=False)

# %%
# menggabungkan submission ke data test
test['Survived'] = submission['Survived']
test.head()
# Out:
#    Pclass  Sex   Age  SibSp  Parch     Fare  C  Q  S  Title  Survived
# 0       3    1  34.5      0      0   7.8292  0  0  1      0         0
# 1       3    0  47.0      1      0   7.0000  1  0  0      2         1
# 2       2    1  62.0      0      0   9.6875  0  0  1      0         0
# 3       3    1  27.0      0      0   8.6625  0  0  1      0         0
# 4       3    0  22.0      1      1  12.2875  0  0  1      2         1
